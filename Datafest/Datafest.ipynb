# %%
# state the website is most used
    # which race is mostly used 
# most commonly asked questions
# questions asked among different states and income

# %%
from sklearn.impute import SimpleImputer
import sys

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
questionposts = pd.read_csv('/Users/aaron/Datafest/data/questionposts.csv', usecols = [0, 3])
# Out:
# /var/folders/ww/pwzgz7r900z34m5y849h5wc80000gn/T/ipykernel_879/834328444.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   questionposts = pd.read_csv('/Users/aaron/Datafest/data/questionposts.csv', usecols = [0, 3])

# %%
questionposts.head()
# Out:
#   Id                                           PostText
# 0  1  Do you still need help with this issue?  It ha...
# 1  2                                            Anyone?
# 2  3  Yes, those are the right forms.  I'm sorry, I ...
# 3  4  Hi ###,You do make some good points.  The diff...
# 4  5  My father passed away and I have DNA test resu...

# %%
attorneys = pd.read_csv('/Users/aaron/Datafest/data/attorneys.csv')

# %%
attorneys.describe()
# Out:
#                  Id    PostalCode
# count  11544.000000  11544.000000
# mean    5772.500000  44193.752339
# std     3332.610088  25594.048590
# min        1.000000      0.000000
# 25%     2886.750000  27513.000000
# 50%     5772.500000  37402.000000
# 75%     8658.250000  64050.000000
# max    11544.000000  99901.000000

# %%
attorneys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11544 entries, 0 to 11543
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           11544 non-null  int64
#  1   StateAbbr    11544 non-null  object
#  2   AttorneyUno  11544 non-null  object
#  3   City         11529 non-null  object
#  4   County       11539 non-null  object
#  5   StateName    11544 non-null  object
#  6   PostalCode   11544 non-null  int64
#  7   CreatedUtc   11544 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 721.6+ KB

# %%
attorneys.head()
# Out:
#    Id StateAbbr                           AttorneyUno          City  \
# 0   1        NH  7A2C12BE-9F37-4C9D-A6ED-41B916820CE0       Concord
# 1   2        NH  29A49AA6-047E-4008-ABBD-3DE57156B526       Concord
# 2   3        MS  9DF11B65-7F29-452C-A69E-54CD72E4A116       Jackson
# 3   4        VA  693FD55F-5F58-405A-B389-5E78B3406497      Richmond
# 4   5        CT  0AC2A866-19CD-4D1A-94B7-BF41A1430553  Wethersfield
#
#             County      StateName  PostalCode           CreatedUtc
# 0         Cheshire  New Hampshire        3301  2019-02-14 16:21:52
# 1        Merrimack  New Hampshire        3229  2019-02-14 18:14:30
# 2           Rankin    Mississippi       39203  2016-08-19 17:07:23
# 3  Richmond (city)       Virginia       23219  2016-08-19 18:22:53
# 4         Hartford    Connecticut        6410  2016-08-21 01:21:13

# %%
attorneryTimeEntries = pd.read_csv('/Users/aaron/Datafest/data/attorneytimeentries.csv')

# %%
attorneryTimeEntries.describe()
# Out:
#                   Id          Hours
# count  114613.000000  114613.000000
# mean    57307.000000       0.391737
# std     33086.067539       0.692430
# min         1.000000       0.000000
# 25%     28654.000000       0.100000
# 50%     57307.000000       0.200000
# 75%     85960.000000       0.400000
# max    114613.000000      49.500000

# %%
attorneryTimeEntries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114613 entries, 0 to 114612
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Id            114613 non-null  int64
#  1   StateAbbr     114613 non-null  object
#  2   TimeEntryUno  114613 non-null  object
#  3   AttorneyUno   114613 non-null  object
#  4   Hours         114613 non-null  float64
#  5   EnteredOnUtc  114613 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.2+ MB

# %%
attorneryTimeEntries.head()
# Out:
#    Id StateAbbr                          TimeEntryUno  \
# 0   1        AK  44954D1D-C354-41F6-8C33-327E866B6BA3
# 1   2        AL  F1D8F733-1BDB-47FD-BC7C-CB512E2C5A3A
# 2   3        AR  81ED2628-2FF4-4B67-86B1-F9DFEC603C15
# 3   4        AZ  14B1BCC4-CEF6-4108-AB54-3CDE482845F0
# 4   5        CA  41275A72-CD69-4A42-85FB-E3E4FEE0C316
#
#                             AttorneyUno  Hours         EnteredOnUtc
# 0  C126C566-9039-4991-BDD8-0CDD05C27DDF    1.8  2017-01-05 21:25:23
# 1  F8C0E3D3-B3A5-42B9-9E2F-2A637BA83D6E    0.4  2020-03-24 01:10:56
# 2  34BFCC3D-B107-4164-B405-DEFF63A65B2D    0.4  2016-12-02 23:21:46
# 3  875DB0F4-619B-4A13-8104-85A3C15D90C4    0.8  2015-12-16 20:32:55
# 4  22746734-D076-4AC8-BA66-50426C01093C    3.0  2020-09-04 00:02:54

# %%
categories = pd.read_csv('/Users/aaron/Datafest/data/categories.csv')

# %%
categories.describe()
# Out:
#                Id
# count  430.000000
# mean   215.500000
# std    124.274562
# min      1.000000
# 25%    108.250000
# 50%    215.500000
# 75%    322.750000
# max    430.000000

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           430 non-null    int64
#  1   StateAbbr    430 non-null    object
#  2   CategoryUno  430 non-null    object
#  3   Category     430 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 13.6+ KB

# %%
categories.head()
# Out:
#    Id StateAbbr                           CategoryUno  \
# 0   1        AK  4CB7A73E-AAB0-4E8F-94D1-8AC8610AAC64
# 1   2        AL  08C7C59B-6AAE-4BC1-83FE-BC85F1544260
# 2   3        AR  FD5059F7-DE7A-4929-8D67-E72C80773BAD
# 3   4        AZ  D90F1BC7-CD04-409A-9AF7-D4DAB649425A
# 4   5        CA  FD678F86-62B1-4EC4-A628-98AEE7BC74D5
#
#                        Category
# 0  Consumer Financial Questions
# 1  Consumer Financial Questions
# 2  Consumer Financial Questions
# 3  Consumer Financial Questions
# 4  Consumer Financial Questions

# %%
clients = pd.read_csv('/Users/aaron/Datafest/data/clients.csv')

# %%
clients.describe()
# Out:
#                   Id     PostalCode            Age  NumberInHousehold  \
# count  331426.000000  314157.000000  279870.000000      280602.000000
# mean   165713.500000   47694.362182      40.338175           2.730316
# std     95674.589496   25690.210708      13.498671           2.076476
# min         1.000000       0.000000       1.000000           1.000000
# 25%     82857.250000   29651.000000      30.000000           1.000000
# 50%    165713.500000   46322.000000      38.000000           2.000000
# 75%    248569.750000   71112.000000      49.000000           4.000000
# max    331426.000000   99999.000000     200.000000         100.000000
#
#        AnnualIncome  AllowedIncome  CheckingBalance  SavingsBalance  \
# count  2.805650e+05   2.806020e+05     2.120200e+05    1.062930e+05
# mean   4.180058e+07   3.686202e+04     5.828651e+06    1.161920e+07
# std    1.901893e+10   2.896496e+04     2.230539e+09    3.150252e+09
# ...

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331426 entries, 0 to 331425
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Id                  331426 non-null  int64
#  1   StateAbbr           331426 non-null  object
#  2   ClientUno           331426 non-null  object
#  3   County              331180 non-null  object
#  4   StateName           331426 non-null  object
#  5   PostalCode          314157 non-null  float64
#  6   EthnicIdentity      278298 non-null  object
#  7   Age                 279870 non-null  float64
#  8   Gender              280227 non-null  object
#  9   MaritalStatus       279548 non-null  object
#  10  Veteran             269757 non-null  object
#  11  Imprisoned          280602 non-null  object
#  12  NumberInHousehold   280602 non-null  float64
#  13  AnnualIncome        280565 non-null  float64
#  14  AllowedIncome       280602 non-null  float64
# ...

# %%
clients.head()
# Out:
#    Id StateAbbr                             ClientUno      County  \
# 0   1        MS  B731DA7A-A97A-4A2E-BF11-0A126A05AF70  Washington
# 1   2        MS  8101DB7C-0CC8-4DE9-9E87-71137269AAD5    Harrison
# 2   3        GA  DD5F1EFC-8298-457F-BC09-CABBEB57A697      Barrow
# 3   4        TX  21DC9E3D-D0AA-4B85-88BB-428F5BCF7F13     Lubbock
# 4   5        ID  3782D4F9-9B16-4BC8-ADA3-F85CEE200630       Boise
#
#      StateName  PostalCode      EthnicIdentity   Age  Gender  \
# 0  Mississippi     73179.0                 NaN   NaN     NaN
# 1  Mississippi     39560.0           Caucasian   NaN    Male
# 2      Georgia     30157.0  Latino or Hispanic  55.0    Male
# 3        Texas     79416.0               Other  61.0  Female
# 4        Idaho     83705.0           Caucasian  65.0    Male
#
#          MaritalStatus Veteran Imprisoned  NumberInHousehold  AnnualIncome  \
# 0                  NaN     NaN         No                3.0       26000.0
# ...

# %%
questions = pd.read_csv('/Users/aaron/Datafest/data/questions.csv')

# %%
questions.describe()
# Out:
#                   Id
# count  202879.000000
# mean   101440.000000
# std     58566.266969
# min         1.000000
# 25%     50720.500000
# 50%    101440.000000
# 75%    152159.500000
# max    202879.000000

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202879 entries, 0 to 202878
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Id                   202879 non-null  int64
#  1   StateAbbr            202879 non-null  object
#  2   QuestionUno          202879 non-null  object
#  3   CategoryUno          202879 non-null  object
#  4   Category             202879 non-null  object
#  5   SubcategoryUno       202879 non-null  object
#  6   Subcategory          202879 non-null  object
#  7   AskedByClientUno     202841 non-null  object
#  8   AskedOnUtc           202879 non-null  object
#  9   TakenByAttorneyUno   144005 non-null  object
#  10  TakenOnUtc           145651 non-null  object
#  11  ClosedByAttorneyUno  137787 non-null  object
#  12  ClosedOnUtc          199085 non-null  object
#  13  LegalDeadline        43944 non-null   object
# dtypes: int64(1), object(13)
# ...

# %%
questions.head()
# Out:
#    Id StateAbbr                           QuestionUno  \
# 0   1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1   2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2   3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3   4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4   5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
#
#                             CategoryUno                      Category  \
# 0  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 1  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 2  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 3  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 4  F6016FBD-9501-4448-BCD3-BBB0E834E33B  Consumer Financial Questions
#
#                          SubcategoryUno  \
# 0  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 1  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 2  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 3  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# ...

# %%
statesites = pd.read_csv('/Users/aaron/Datafest/data/statesites.csv')

# %%
statesites.describe()
# Out:
#               Id  AllowedAssets  BaseIncomeLimit  \
# count  42.000000      42.000000        42.000000
# mean   21.500000   92142.857143     13638.571429
# std    12.267844  184622.696518       314.778834
# min     1.000000   10000.000000     13590.000000
# 25%    11.250000   10000.000000     13590.000000
# 50%    21.500000   10000.000000     13590.000000
# 75%    31.750000   10000.000000     13590.000000
# max    42.000000  500000.000000     15630.000000
#
#        PerHouseholdMemberIncomeLimit  IncomeMultiplier
# count                      42.000000         42.000000
# mean                     4736.904762          2.869048
# std                       109.555378          0.653877
# min                      4720.000000          2.000000
# 25%                      4720.000000          2.500000
# 50%                      4720.000000          2.500000
# 75%                      4720.000000          3.000000
# max                      5430.000000          4.000000

# %%
statesites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Id                             42 non-null     int64
#  1   StateAbbr                      42 non-null     object
#  2   StateName                      42 non-null     object
#  3   AllowedAssets                  42 non-null     int64
#  4   BaseIncomeLimit                42 non-null     int64
#  5   PerHouseholdMemberIncomeLimit  42 non-null     int64
#  6   IncomeMultiplier               42 non-null     float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 2.4+ KB

# %%
statesites.head()
# Out:
#    Id StateAbbr    StateName  AllowedAssets  BaseIncomeLimit  \
# 0   1        AL      Alabama          10000            13590
# 1   2        AR     Arkansas          10000            13590
# 2   3        AZ      Arizona          10000            13590
# 3   4        CA   California          10000            13590
# 4   5        CT  Connecticut          10000            13590
#
#    PerHouseholdMemberIncomeLimit  IncomeMultiplier
# 0                           4720               2.5
# 1                           4720               2.5
# 2                           4720               2.5
# 3                           4720               4.0
# 4                           4720               2.5

# %%
statesites.shape
# Out:
# (42, 7)

# %%
subcategories = pd.read_csv('/Users/aaron/Datafest/data/subcategories.csv')

# %%
subcategories.describe()
# Out:
#               Id
# count  966.00000
# mean   483.50000
# std    279.00448
# min      1.00000
# 25%    242.25000
# 50%    483.50000
# 75%    724.75000
# max    966.00000

# %%
subcategories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              966 non-null    int64
#  1   StateAbbr       966 non-null    object
#  2   CategoryUno     966 non-null    object
#  3   SubcategoryUno  966 non-null    object
#  4   Subcategory     959 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 37.9+ KB

# %%
subcategories.head()
# Out:
#    Id StateAbbr                           CategoryUno  \
# 0   1        AK  2D43B4FD-FAC8-47C3-A891-085F5D74D64B
# 1   2        AK  2D43B4FD-FAC8-47C3-A891-085F5D74D64B
# 2   3        AK  2D43B4FD-FAC8-47C3-A891-085F5D74D64B
# 3   4        AK  D3504F18-AC99-408B-B1D2-230DC130F9EC
# 4   5        AK  BF144F3C-5743-47C5-9EEB-418FF0FAF0D8
#
#                          SubcategoryUno                   Subcategory
# 0  546C6AD6-4D2B-4B1D-B09F-8016C5B02D66              COVID-19-Housing
# 1  572148E8-96C7-4B74-8280-B749191C5B4C            COVID-19-Insurance
# 2  5AA5088E-3A9D-4D99-B6FE-69122C34194A       COVID-19-Lost Documents
# 3  E5DF5CEB-649F-47B3-B665-1BEB3EA4AD42  Emancipation and Delinquency
# 4  16E4350E-BC59-40B7-BF72-0BC225ECA4D1                   Immigration

# %%
# for clients, we can maybe remove NAN values
# remove veteran 

# for questions, group by the question type to see what they have

# %%
clients["EthnicIdentity"].isna().sum()
# Out:
# 53128

# %%
clients.groupby("EthnicIdentity").mean()
# Out:
#                                                                Id  \
# EthnicIdentity
# African                                             157142.250535
# African American                                    167747.213392
# African American,African                            166838.150794
# African American,African,Arab                       161551.500000
# African American,African,Arab,Asian,Caucasian,E...   71488.000000
# ...                                                           ...
# Native Hawaiian / Pacific Islander,Other            102872.545455
# Not Hispanic or Latino                              247295.079582
# Other                                               158105.686714
# Slavic                                              170157.493802
# Slavic,Other                                        185080.384615
#
#                                                       PostalCode        Age  \
# EthnicIdentity
# ...

# %%
newClients = clients.dropna(subset = ["EthnicIdentity", "Age", "CheckingBalance", "SavingsBalance"])

# %%
newClients["EthnicIdentity"].isna().sum()
# Out:
# 0

# %%
newClients.groupby("EthnicIdentity").count()
# Out:
#                                                        Id  StateAbbr  \
# EthnicIdentity
# African                                               311        311
# African American                                    11237      11237
# African American,African                               52         52
# African American,African,Arab,Asian,Caucasian,E...      1          1
# African American,African,Arab,Asian,Caucasian,E...      1          1
# ...                                                   ...        ...
# Native Hawaiian / Pacific Islander,Other                5          5
# Not Hispanic or Latino                               9700       9700
# Other                                                1842       1842
# Slavic                                                158        158
# Slavic,Other                                            3          3
#
#                                                     ClientUno  County  \
# EthnicIdentity
# ...

# %%
newClients['EthnicIdentity'].value_counts().sort_values()
# Out:
# African American,African,Caucasian,Latino or Hispanic,Other                  1
# African,Caucasian,Latino or Hispanic,Native American or Alaska Native        1
# African American,Asian,Caucasian,Latino or Hispanic                          1
# Caucasian,Native American or Alaska Native,Slavic,Other                      1
# African American,African,Arab,Asian,East Indian                              1
#                                                                          ...
# Latino or Hispanic                                                        6260
# I'd rather not answer                                                     6406
# Not Hispanic or Latino                                                    9700
# African American                                                         11237
# Caucasian                                                                45873
# Name: EthnicIdentity, Length: 191, dtype: int64

# %%
AA_data = newClients[newClients['EthnicIdentity'] == 'African American']

# %%
print(attorneys['StateName'].value_counts().sort_values(),
      AA_data['StateAbbr'].value_counts().sort_values())
# Out:
# North Dakota              1
# Idaho                     2
# U.S. Virgin Islands       3
# South Dakota             26
# Kansas                   30
# Vermont                  54
# Wyoming                  62
# Iowa                     67
# New Jersey               74
# Michigan                 77
# ABA Federal              89
# New Mexico               94
# Utah                     97
# Pennsylvania             98
# Connecticut             103
# Arizona                 104
# Alaska                  110
# New Hampshire           123
# Hawaii                  125
# Mississippi             138
# Alabama                 138
# Oklahoma                167
# West Virginia           175
# Arkansas                192
# Maine                   193
# California              245
# Louisiana               246
# South Carolina          260
# Maryland                262
# Nebraska                266
# Georgia                 308
# Missouri                315
# Wisconsin               385
# ...

# %%
AA_data['AnnualIncome'].hist(by = AA_data["StateName"], range = [0, 300], figsize = (5, 10))
plt.show()

# %%
questions["Category"].value_counts()
# Out:
# Family and Children                  88753
# Other                                37053
# Housing and Homelessness             34755
# Consumer Financial Questions         17273
# Work, Employment and Unemployment    10187
# Individual Rights                     8312
# Health and Disability                 2707
# Income Maintenance                    2688
# Education                              794
# Juvenile                               357
# Name: Category, dtype: int64

# %%
questions.head()
# Out:
#    Id StateAbbr                           QuestionUno  \
# 0   1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1   2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2   3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3   4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4   5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
#
#                             CategoryUno                      Category  \
# 0  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 1  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 2  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 3  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 4  F6016FBD-9501-4448-BCD3-BBB0E834E33B  Consumer Financial Questions
#
#                          SubcategoryUno  \
# 0  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 1  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 2  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 3  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# ...

# %%
date = []
for i in range(0, len(questions['AskedOnUtc'])):
    date.append(questions['AskedOnUtc'][i].split('-')[0])

# %%
questions["Date"] = date

# %%
questions["Date"].value_counts()
# Out:
# 2021    52873
# 2020    46220
# 2019    32686
# 2018    31056
# 2017    20610
# 2016     7826
# 2022     3521
# 2015     3433
# 2014     2786
# 2013     1787
# 2012       81
# Name: Date, dtype: int64

# %%
month = []
for i in range(0, len(questions['AskedOnUtc'])):
    month.append(questions['AskedOnUtc'][i].split('-')[1])

# %%
questions['Month'] = month

# %%
questions2021 = questions[questions["Date"] == '2021']

# %%
for i in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']:
    print(questions2021[questions2021['Month'] == i]['Category'].value_counts())
# Out:
# Family and Children                  2117
# Other                                1006
# Housing and Homelessness              851
# Consumer Financial Questions          407
# Work, Employment and Unemployment     293
# Individual Rights                     212
# Income Maintenance                     73
# Health and Disability                  67
# Education                              14
# Juvenile                               10
# Name: Category, dtype: int64
# Family and Children                  1749
# Other                                 857
# Housing and Homelessness              826
# Consumer Financial Questions          388
# Work, Employment and Unemployment     257
# Individual Rights                     184
# Health and Disability                  67
# Income Maintenance                     50
# Juvenile                               15
# Education                               6
# Name: Category, dtype: int64
# Family and Children                  1765
# ...

# %%
questions2020 = questions[questions["Date"] == '2020']

# %%
for i in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']:
    print(questions2020[questions2020['Month'] == i]['Subcategory'].value_counts())
# Out:
# Family/Divorce/Custody                                 610
# Other                                                  314
# Family/Divorce/Custody/Adoption                        150
# Debts & Purchases                                      137
# Housing or Property Owned                              131
#                                                       ...
# Taxes                                                    1
# Domestic Abuse/Protection or Harassment Order            1
# Veterans Benefits                                        1
# Natural Disaster                                         1
# Collection (Repossession, Delinquency, Garnishment)      1
# Name: Subcategory, Length: 188, dtype: int64
# Family/Divorce/Custody             512
# Other                              313
# Family/Divorce/Custody/Adoption    127
# Debts & Purchases                  121
# Housing or Property Owned          108
#                                   ...
# ...

# %%
attorneryTimeEntries.head()
# Out:
#    Id StateAbbr                          TimeEntryUno  \
# 0   1        AK  44954D1D-C354-41F6-8C33-327E866B6BA3
# 1   2        AL  F1D8F733-1BDB-47FD-BC7C-CB512E2C5A3A
# 2   3        AR  81ED2628-2FF4-4B67-86B1-F9DFEC603C15
# 3   4        AZ  14B1BCC4-CEF6-4108-AB54-3CDE482845F0
# 4   5        CA  41275A72-CD69-4A42-85FB-E3E4FEE0C316
#
#                             AttorneyUno  Hours         EnteredOnUtc
# 0  C126C566-9039-4991-BDD8-0CDD05C27DDF    1.8  2017-01-05 21:25:23
# 1  F8C0E3D3-B3A5-42B9-9E2F-2A637BA83D6E    0.4  2020-03-24 01:10:56
# 2  34BFCC3D-B107-4164-B405-DEFF63A65B2D    0.4  2016-12-02 23:21:46
# 3  875DB0F4-619B-4A13-8104-85A3C15D90C4    0.8  2015-12-16 20:32:55
# 4  22746734-D076-4AC8-BA66-50426C01093C    3.0  2020-09-04 00:02:54

# %%
yearAttTime = []
for i in range(0, len(attorneryTimeEntries['EnteredOnUtc'])):
    yearAttTime.append(attorneryTimeEntries['EnteredOnUtc'][i].split('-')[0])

# %%
attorneryTimeEntries['Year'] = yearAttTime

# %%
monthAttTime = []
for i in range(0, len(attorneryTimeEntries['EnteredOnUtc'])):
    monthAttTime.append(attorneryTimeEntries['EnteredOnUtc'][i].split('-')[1])

# %%
attorneryTimeEntries['Month'] = monthAttTime

# %%
attorneryTimeEntries2021 = attorneryTimeEntries[attorneryTimeEntries["Year"] == '2021']
attorneryTimeEntries2020 = attorneryTimeEntries[attorneryTimeEntries["Year"] == '2020']

# %%
for i in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']:
    print(i, sum(attorneryTimeEntries2021['Month'] == i))
# Out:
# 01 3445
# 02 3422
# 03 3416
# 04 3121
# 05 2813
# 06 3150
# 07 3035
# 08 2926
# 09 3033
# 10 3265
# 11 2763
# 12 2930

# %%
for i in ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']:
    print(i, sum(attorneryTimeEntries2020['Month'] == i))
# Out:
# 01 1712
# 02 1728
# 03 2112
# 04 2726
# 05 2871
# 06 2767
# 07 3250
# 08 3712
# 09 3472
# 10 3438
# 11 2978
# 12 3594

# %%
# so we have this data, we want a heat map of the states of which type of question is asked
# relate it to income

# %%
questions_clean = questions.dropna(subset = ['StateAbbr'])

# %%
cat_cols = questions_clean.select_dtypes(include=["object"]).columns
cat_cols
# Out:
# Index(['StateAbbr', 'QuestionUno', 'CategoryUno', 'Category', 'SubcategoryUno',
#        'Subcategory', 'AskedByClientUno', 'AskedOnUtc', 'TakenByAttorneyUno',
#        'TakenOnUtc', 'ClosedByAttorneyUno', 'ClosedOnUtc', 'LegalDeadline',
#        'Date', 'Month'],
#       dtype='object')

# %%
questions_clean.groupby("StateAbbr")['Category'].apply(lambda x: x.mode()[0])
# Out:
# StateAbbr
# AK         Family and Children
# AL         Family and Children
# AR         Family and Children
# AZ         Family and Children
# CA                       Other
# CT         Family and Children
# FL         Family and Children
# GA         Family and Children
# HI         Family and Children
# IA         Family and Children
# ID                       Other
# IL         Family and Children
# IN         Family and Children
# KS         Family and Children
# LA         Family and Children
# MA    Housing and Homelessness
# MD         Family and Children
# ME         Family and Children
# MI         Family and Children
# MO         Family and Children
# MS         Family and Children
# NC         Family and Children
# NE         Family and Children
# NH         Family and Children
# NJ         Family and Children
# NM         Family and Children
# NY                       Other
# OK         Family and Children
# PA         Family and Children
# ...

# %%
questions_clean.groupby("StateAbbr")['Subcategory'].apply(lambda x: x.mode()[0])
# Out:
# StateAbbr
# AK                               Family/Divorce/Custody
# AL                               Family/Divorce/Custody
# AR                     Family Law or Divorce or Custody
# AZ                               Family/Divorce/Custody
# CA            Wildfire or COVID-19: Other related issue
# CT                               Family/Divorce/Custody
# FL                               Family/Divorce/Custody
# GA                               Family/Divorce/Custody
# HI                     Family/Divorce/Custody/Paternity
# IA                               Family/Divorce/Custody
# ID                                                Other
# IL                        Family/Safety/Divorce/Custody
# IN                          Custody & Visitation issues
# KS                               Family/Divorce/Custody
# LA                               Family/Divorce/Custody
# MA                               Housing or Real Estate
# MD                               Family/Divorce/Custody
# ...

# %%
sorted(questions_clean["StateAbbr"].unique())
# Out:
# ['AK',
#  'AL',
#  'AR',
#  'AZ',
#  'CA',
#  'CT',
#  'FL',
#  'GA',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'LA',
#  'MA',
#  'MD',
#  'ME',
#  'MI',
#  'MO',
#  'MS',
#  'NC',
#  'NE',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'OK',
#  'PA',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'US',
#  'UT',
#  'VA',
#  'VT',
#  'WI',
#  'WV',
#  'WY']

# %%
stateName = sorted(questions_clean["StateAbbr"].unique())
for i in stateName:
    print("Statname: ", i, " ", questions_clean.groupby("StateAbbr").get_group(i).groupby("Subcategory")["Id"].count())
# Out:
# Statname:  AK   Subcategory
# Benefits                                   9
# COVID-19-Employment                        4
# COVID-19â€”Consumer                        2
# COVID-19â€”Healthcare                      5
# COVID-19â€”Housing                        22
# COVID-19â€”Wills/Probate                   3
# Civil/Constitutional Rights               32
# Debts & Purchases                         52
# Expungement                                6
# Family/Divorce/Custody                   376
# Health Care                                7
# Housing or Property Owned                114
# Immigration                                7
# Medicaid/Medicare/Affordable Care Act      3
# Other                                    145
# Personal Injury                           21
# School Discipline                          1
# Wills/Inheritance                         25
# Work                                      26
# Worker's Comp                              2
# Name: Id, dtype: int64
# ...

# %%
hoursAtt = list(attorneryTimeEntries.groupby("StateAbbr")["Hours"].mean())
subCat = list(questions_clean.groupby("StateAbbr")['Subcategory'].apply(lambda x: x.mode()[0]))
subCat = subCat[:33] + subCat[34:]
Cat = list(questions_clean.groupby("StateAbbr")['Category'].apply(lambda x: x.mode()[0]))
Cat = Cat[:33] + Cat[34:]
# stateName
stateName = stateName[:33] + stateName[34:]

# %%
stateData = pd.DataFrame({"State":stateName, "Avg_Attornery_spent":hoursAtt,
                          "sub_category":subCat, "category":Cat})

# %%
stateData
# Out:
#    State  Avg_Attornery_spent  \
# 0     AK             0.322164
# 1     AL             0.287148
# 2     AR             0.264193
# 3     AZ             0.402731
# 4     CA             1.301092
# 5     CT             0.373056
# 6     FL             0.276496
# 7     GA             0.390888
# 8     HI             0.354052
# 9     IA             0.239230
# 10    ID             0.419025
# 11    IL             0.405406
# 12    IN             0.366667
# 13    KS             0.343922
# 14    LA             0.538548
# 15    MA             0.411231
# 16    MD             0.371341
# 17    ME             1.360000
# 18    MI             0.275845
# 19    MO             0.473504
# 20    MS             0.308642
# 21    NC             0.429312
# 22    NE             0.330462
# 23    NH             0.353425
# 24    NJ             0.280505
# 25    NM             0.316964
# 26    NY             0.296049
# 27    OK             0.498726
# 28    PA             0.363514
# 29    SC             0.989474
# ...

# %%
# Out:
# array(['NC', 'NJ', 'FL', 'MO', 'MA', 'TX', 'PA', 'AZ', 'MD', 'NE', 'MI',
#        'NY', 'SC', 'CA', 'SD', 'VA', 'VT', 'WI', 'IA', 'IL', 'WV', 'AR',
#        'AK', 'ME', 'HI', 'IN', 'GA', 'TN', 'ID', 'NM', 'LA', 'NH', 'AL',
#        'OK', 'US', 'UT', 'MS', 'CT', 'KS', 'WY'], dtype=object)

# %%
# Out:
# StateAbbr
# AK         Family and Children
# AL         Family and Children
# AR         Family and Children
# AZ         Family and Children
# CA                       Other
# CT         Family and Children
# FL         Family and Children
# GA         Family and Children
# HI         Family and Children
# IA         Family and Children
# ID                       Other
# IL         Family and Children
# IN         Family and Children
# KS         Family and Children
# LA         Family and Children
# MA    Housing and Homelessness
# MD         Family and Children
# ME         Family and Children
# MI         Family and Children
# MO         Family and Children
# MS         Family and Children
# NC         Family and Children
# NE         Family and Children
# NH         Family and Children
# NJ         Family and Children
# NM         Family and Children
# NY                       Other
# OK         Family and Children
# PA         Family and Children
# ...
